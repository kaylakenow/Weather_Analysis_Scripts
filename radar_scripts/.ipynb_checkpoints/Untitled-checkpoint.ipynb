# %% [markdown]
# # Radar Mosiac Plotting
#
# This notebook is an example of downloading, gridding, and plotting radar mosiacs

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import pyart

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import boto3
from botocore import UNSIGNED
from botocore.config import Config

from datetime import datetime, timedelta
from netCDF4 import Dataset

import glob
import os

import pandas as pd

import numpy as np

# %%
#set date and location bounds
#set time to plot (no leading zeros)
year  = 2021
month = 12
day   = 10
hour  = 18
minute   = 0
    
lat_min = 30
lat_max = 50
lon_min = -115
lon_max = -75

# %%
#read in radar_list
df = pd.read_csv('radar_list.txt',delimiter='|',header=None,
                 names=['radar_name','radar_name2','lat','lon','elv','code','state','location'],
                 dtype={'lat':float, 'lon':float, 'elv':float})

df.radar_name = df.radar_name.str.upper()

#remove if not within 1 deg of area to be plotted
#1 deg is about 100 km
to_del = np.where( (df.lat>lat_max+1) | (df.lat<lat_min-1) |
                   (df.lon>lon_max+1) | (df.lon<lon_min-1) ) 

df.drop(to_del[0],inplace=True)

# %%
#grab data for requested date and all radars within bounds
dt = datetime(year,month,day,hour,minute)

for file in glob.glob('radar_data/*'):
        os.remove(file)

noaa_bucket = 'noaa-nexrad-level2'

s3 = boto3.resource('s3', config=Config(signature_version=UNSIGNED))
s3_client = boto3.client('s3', config=Config(signature_version=UNSIGNED))
bucket = s3.Bucket(noaa_bucket)

start = datetime.utcnow()

for radar in df.radar_name:
    if radar[0] == "T":
        continue
    path = f'{dt:%Y}/{dt:%m}/{dt:%d}/{radar}/{radar}{dt:%Y}{dt:%m}{dt:%d}_{dt:%H}'
    objs = bucket.objects.filter(Prefix=path)
    files = np.array([i.key for i in objs])
    inds_keep = []
    for i, s in enumerate(files):
        if "_MDM" in s:
            pass
        else: 
            inds_keep.append(i)
    files = files[inds_keep]
    
    
    if len(files) == 0:
        continue
    file_time = np.array([datetime.strptime(i[20:35],'%Y%m%d_%H%M%S') for i in files])
    delta_t = np.array([abs((dt - i)).seconds for i in file_time])
    file = files[np.argmin(delta_t)]
    outfile = file.split('/')[-1]
    
    print(f'Downloading {radar}')
    s3_client.download_file(noaa_bucket,file,f'./radar_data/{outfile}')
    print(f' Total time elapsed: {(datetime.utcnow()-start).seconds} seconds')
#file_time = np.array([datetime.strptime(i[
#start_times = np.array([datetime.strptime(i[52:65],'%Y%j%H%M%S') for i in files])
#end_times = np.array([datetime.strptime(i[68:81],'%Y%j%H%M%S') for i in files])
#print(files)
#delta_t = np.array([abs((dt - i)).seconds for i in start_times])
#file = files[np.argmin(delta_t)]

#if os.path.exists("tmp.nc"):
#    os.remove("tmp.nc")

    
#print(file)
#s3_client.download_file(noaa_bucket, file, 'tmp.nc')
#bucket/2024/01/01/KAMX/KAMX20240101_004714_V06

#path = f'{prod}/{dt:%Y}/{dt:%j}/{dt:%H}/OR_{prod}-M6C{channel}_'
#objs = bucket.objects.filter(Prefix=path)
#files = np.array([i.key for i in objs])

#if len(files) == 0:
#    path = f'{prod}/{dt:%Y}/{dt:%j}/{dt:%H}/OR_{prod}-M3C{channel}_'
#    objs = bucket.objects.filter(Prefix=path)
#    files = np.array([i.key for i in objs])
# Out:
# Downloading KBMX
#  Total time elapsed: 4 seconds
# Downloading KEOX
#  Total time elapsed: 5 seconds
# Downloading KHTX
#  Total time elapsed: 6 seconds
# Downloading KMXX
#  Total time elapsed: 8 seconds
# Downloading KMOB
#  Total time elapsed: 9 seconds
# Downloading KSRX
#  Total time elapsed: 12 seconds
# Downloading KLZK
#  Total time elapsed: 13 seconds
# Downloading KFSX
#  Total time elapsed: 14 seconds
# Downloading KIWA
#  Total time elapsed: 15 seconds
# Downloading KEMX
#  Total time elapsed: 17 seconds
# Downloading KFTG
#  Total time elapsed: 20 seconds
# Downloading KGJX
#  Total time elapsed: 22 seconds
# Downloading KPUX
#  Total time elapsed: 25 seconds
# Downloading KDOX
#  Total time elapsed: 26 seconds
# Downloading KEVX
#  Total time elapsed: 28 seconds
# Downloading KJAX
#  Total time elapsed: 29 seconds
# Downloading KTLH
#  Total time elapsed: 30 seconds
# Downloading KFFC
#  Total time elapsed: 32 seconds
# Downloading KVAX
#  Total time elapsed: 35 seconds
# Downloading KJGX
#  Total time elapsed: 37 seconds
# Downloading KDMX
#  Total time elapsed: 39 seconds
# Downloading KDVN
#  Total time elapsed: 41 seconds
# Downloading KSFX
#  Total time elapsed: 42 seconds
# Downloading KLOT
#  Total time elapsed: 44 seconds
# Downloading KILX
#  Total time elapsed: 46 seconds
# Downloading KVWX
#  Total time elapsed: 48 seconds
# Downloading KIWX
#  Total time elapsed: 49 seconds
# Downloading KIND
#  Total time elapsed: 51 seconds
# Downloading KDDC
#  Total time elapsed: 53 seconds
# Downloading KGLD
#  Total time elapsed: 54 seconds
# Downloading KTWX
#  Total time elapsed: 55 seconds
# Downloading KICT
#  Total time elapsed: 57 seconds
# Downloading KHPX
#  Total time elapsed: 58 seconds
# Downloading KJKL
#  Total time elapsed: 60 seconds
# Downloading KLVX
#  Total time elapsed: 61 seconds
# Downloading KPAH
#  Total time elapsed: 62 seconds
# Downloading KPOE
#  Total time elapsed: 64 seconds
# Downloading KLCH
#  Total time elapsed: 65 seconds
# Downloading KLIX
#  Total time elapsed: 67 seconds
# Downloading KSHV
#  Total time elapsed: 69 seconds
# Downloading KDTX
#  Total time elapsed: 69 seconds
# Downloading KAPX
#  Total time elapsed: 71 seconds
# Downloading KGRR
#  Total time elapsed: 72 seconds
# Downloading KMQT
#  Total time elapsed: 72 seconds
# Downloading KDLH
#  Total time elapsed: 74 seconds
# Downloading KMPX
#  Total time elapsed: 76 seconds
# Downloading KEAX
#  Total time elapsed: 80 seconds
# Downloading KSGF
#  Total time elapsed: 82 seconds
# Downloading KLSX
#  Total time elapsed: 84 seconds
# Downloading KGWX
#  Total time elapsed: 85 seconds
# Downloading KDGX
#  Total time elapsed: 93 seconds
# Downloading KBLX
#  Total time elapsed: 94 seconds
# Downloading KGGW
#  Total time elapsed: 96 seconds
# Downloading KTFX
#  Total time elapsed: 97 seconds
# Downloading KMSX
#  Total time elapsed: 100 seconds
# Downloading KMHX
#  Total time elapsed: 102 seconds
# Downloading KRAX
#  Total time elapsed: 105 seconds
# Downloading KLTX
#  Total time elapsed: 107 seconds
# Downloading KBIS
#  Total time elapsed: 108 seconds
# Downloading KMVX
#  Total time elapsed: 109 seconds
# Downloading KMBX
#  Total time elapsed: 110 seconds
# Downloading KUEX
#  Total time elapsed: 111 seconds
# Downloading KLNX
#  Total time elapsed: 113 seconds
# Downloading KOAX
#  Total time elapsed: 114 seconds
# Downloading KABX
#  Total time elapsed: 115 seconds
# Downloading KFDX
#  Total time elapsed: 115 seconds
# Downloading KHDX
#  Total time elapsed: 116 seconds
# Downloading KESX
#  Total time elapsed: 117 seconds
# Downloading KENX
#  Total time elapsed: 119 seconds
# Downloading KBGM
#  Total time elapsed: 119 seconds
# Downloading KBUF
#  Total time elapsed: 120 seconds
# Downloading KTYX
#  Total time elapsed: 121 seconds
# Downloading KCLE
#  Total time elapsed: 122 seconds
# Downloading KILN
#  Total time elapsed: 123 seconds
# Downloading KTLX
#  Total time elapsed: 126 seconds
# Downloading KINX
#  Total time elapsed: 130 seconds
# Downloading KVNX
#  Total time elapsed: 131 seconds
# Downloading KDIX
#  Total time elapsed: 132 seconds
# Downloading KPBZ
#  Total time elapsed: 133 seconds
# Downloading KCCX
#  Total time elapsed: 134 seconds
# Downloading KCLX
#  Total time elapsed: 137 seconds
# Downloading KCAE
#  Total time elapsed: 140 seconds
# Downloading KGSP
#  Total time elapsed: 141 seconds
# Downloading KABR
#  Total time elapsed: 144 seconds
# Downloading KUDX
#  Total time elapsed: 146 seconds
# Downloading KFSD
#  Total time elapsed: 149 seconds
# Downloading KMRX
#  Total time elapsed: 151 seconds
# Downloading KNQA
#  Total time elapsed: 153 seconds
# Downloading KOHX
#  Total time elapsed: 154 seconds
# Downloading KAMA
#  Total time elapsed: 155 seconds
# Downloading KGRK
#  Total time elapsed: 156 seconds
# Downloading KFWS
#  Total time elapsed: 158 seconds
# Downloading KEPZ
#  Total time elapsed: 158 seconds
# Downloading KHGX
#  Total time elapsed: 160 seconds
# Downloading KDFX
#  Total time elapsed: 161 seconds
# Downloading KLBB
#  Total time elapsed: 162 seconds
# Downloading KMAF
#  Total time elapsed: 162 seconds
# Downloading KSJT
#  Total time elapsed: 163 seconds
# Downloading KEWX
#  Total time elapsed: 164 seconds
# Downloading KICX
#  Total time elapsed: 165 seconds
# Downloading KMTX
#  Total time elapsed: 166 seconds
# Downloading KFCX
#  Total time elapsed: 167 seconds
# Downloading KLWX
#  Total time elapsed: 168 seconds
# Downloading KAKQ
#  Total time elapsed: 169 seconds
# Downloading KGRB
#  Total time elapsed: 169 seconds
# Downloading KARX
#  Total time elapsed: 171 seconds
# Downloading KMKX
#  Total time elapsed: 172 seconds
# Downloading KRLX
#  Total time elapsed: 173 seconds
# Downloading KCYS
#  Total time elapsed: 173 seconds
# Downloading KRIW
#  Total time elapsed: 174 seconds

# %%
radar_files = glob.glob('./radar_data/*')
radar_data = [None] * len(radar_files)

for i in range(len(radar_files)):
    print(f'Reading radar {i+1} of {len(radar_files)}')
    radar_data[i] = pyart.io.read_nexrad_archive(radar_files[i])
# Out:
# Reading radar 1 of 110
# Reading radar 2 of 110
# Reading radar 3 of 110
